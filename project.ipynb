# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('NFDB_point_20220901.txt', sep=",", header=None)

df.head(5)
# Out:
# /var/folders/_1/slbty4054pvb722zx16dmj7w0000gn/T/ipykernel_75398/1695742249.py:6: DtypeWarning: Columns (0,4,5,6,7,8,10,11,13,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NFDB_point_20220901.txt', sep=",", header=None)
#     0           1            2         3                   4   \
# 0  FID  SRC_AGENCY      FIRE_ID  FIRENAME            LATITUDE
# 1    0          BC  1953-G00041            59.963000000000001
# 2    1          BC  1950-R00028            59.317999999999998
# 3    2          BC  1950-G00026            59.875999999999998
# 4    3          BC  1951-R00097            59.759999999999998
#
#                      5     6      7    8                    9   ...  \
# 0             LONGITUDE  YEAR  MONTH  DAY             REP_DATE  ...
# 1  -128.172000000000000  1953      5   26  1953-05-26 00:00:00  ...
# 2  -132.172000000000000  1950      6   22  1950-06-22 00:00:00  ...
# ...

# %%
# get counts of number of unique values in src_agency column
df[1].value_counts()
# Out:
# 1
# BC            149410
# ON             63508
# AB             62707
# QC             43124
# MB             27508
# SK             25287
# NT             14365
# NB             11041
# NS             10451
# YT              8061
# NL              4372
# PC-WB           1961
# PC-BA            353
# PC-JA            259
# PC-GF            167
# PC-KO            147
# PC-GR            145
# PC-PA            130
# PC-GL            106
# PC-RM             92
# PC-NA             78
# PC-YO             75
# PC-WL             65
# PC-LM             60
# PC-PU             59
# PC-RE             49
# PC-EI             35
# PC-KG             30
# PC-PP             26
# PC-GI             20
# PC-TN             17
# PC-CB             17
# PC-KE             14
# PC-BP             12
# PC-TI             10
# PC-SL              8
# PC-BT              8
# PC-WP              8
# PC-FO              6
# PC-KL              5
# PC-PE              4
# PC-FR              3
# PC-VU              3
# ...

# %%
# find records where SRC_AGENCY is equal to SRC_AGENCY
df[df[1] == 'SRC_AGENCY']
# Out:
#     0           1        2         3         4          5     6      7    8   \
# 0  FID  SRC_AGENCY  FIRE_ID  FIRENAME  LATITUDE  LONGITUDE  YEAR  MONTH  DAY
#
#          9   ...         17          18         19         20        21  \
# 0  REP_DATE  ...  MORE_INFO  CFS_REF_ID  CFS_NOTE1  CFS_NOTE2  ACQ_DATE
#
#          22       23        24         25        26
# 0  SRC_AGY2  ECOZONE  ECOZ_REF  ECOZ_NAME  ECOZ_NOM
#
# [1 rows x 27 columns]

# %%
import pandas as pd
import chardet

# Detect the file's encoding
with open('nfd-statement-of-revenues-from-the-sale-of-timber-from-provincial-crown-land-en-fr-1.csv', 'rb') as f:
    result = chardet.detect(f.read())

# Read the file with the detected encoding
df2 = pd.read_csv('nfd-statement-of-revenues-from-the-sale-of-timber-from-provincial-crown-land-en-fr-1.csv', sep=",", encoding=result['encoding'])

# %%
df2.head()
# Out:
#    Year  Année ISO              Juridiction  \
# 0  2003   2003  NL  Terre-Neuve-et-Labrador
# 1  2003   2003  NL  Terre-Neuve-et-Labrador
# 2  2003   2003  NL  Terre-Neuve-et-Labrador
# 3  2003   2003  NL  Terre-Neuve-et-Labrador
# 4  2003   2003  NL  Terre-Neuve-et-Labrador
#
#                                        Revenues  \
# 0                          Area/holding charges
# 1  Other (bonuses, penalties, interest charges)
# 2                               Protection fees
# 3         Permit and licence fees (export fees)
# 4                             Sales and rentals
#
#                                            Revenus  Value (dollars)  \
# 0              Droits de location ou de jouissance              0.0
# 1  Autres (suppléments, amendes, frais d'intérêts)           3000.0
# 2                 Coût de protection du territoire              0.0
# 3  Permis et frais de tenure (frais d'exportation)         539000.0
# ...

# %%
df2.columns
# Out:
# Index(['Year', 'ISO', 'Revenues', 'Value (dollars)', 'Data qualifier',
#        'Jurisdiction'],
#       dtype='object')

# %%
df2 = df2.drop(columns=['Année', 'Juridiction', 'Revenus', 'Valeur (en dollar)', 'Qualificatifs de données'])

# %%
df2 = df2[df2['Year'] > 2014]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 448 entries, 94 to 2847
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             448 non-null    int64
#  1   ISO              448 non-null    object
#  2   Revenues         448 non-null    object
#  3   Value (dollars)  408 non-null    float64
#  4   Data qualifier   448 non-null    object
#  5   Jurisdiction     448 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 24.5+ KB

# %%
df2
# Out:
#       Year ISO                                      Revenues  Value (dollars)  \
# 94    2015  NL                              Stumpage charges        1369583.0
# 95    2015  NL                                  Rent charges              0.0
# 96    2015  NL                          Area/holding charges              NaN
# 97    2015  NL                          Reforestation levies              NaN
# 98    2015  NL         Permit and licence fees (export fees)         825647.0
# ...    ...  ..                                           ...              ...
# 2843  2018  NT                          Area/holding charges              0.0
# 2844  2019  NT                              Stumpage charges           2410.0
# 2845  2019  NT  Other (bonuses, penalties, interest charges)              0.0
# 2846  2019  NT                             Sales and rentals              0.0
# 2847  2019  NT         Permit and licence fees (export fees)            740.0
#
# ...

# %%
df2 = df2.drop(columns=['Data qualifier'])

# %%
df2
# Out:
#       Year ISO                                      Revenues  Value (dollars)  \
# 94    2015  NL                              Stumpage charges        1369583.0
# 95    2015  NL                                  Rent charges              0.0
# 96    2015  NL                          Area/holding charges              NaN
# 97    2015  NL                          Reforestation levies              NaN
# 98    2015  NL         Permit and licence fees (export fees)         825647.0
# ...    ...  ..                                           ...              ...
# 2843  2018  NT                          Area/holding charges              0.0
# 2844  2019  NT                              Stumpage charges           2410.0
# 2845  2019  NT  Other (bonuses, penalties, interest charges)              0.0
# 2846  2019  NT                             Sales and rentals              0.0
# 2847  2019  NT         Permit and licence fees (export fees)            740.0
#
#                    Jurisdiction
# ...
